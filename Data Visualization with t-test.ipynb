# %%
! pip install numpy
! pip install pandas
! pip install seaborn
! pip install matplotlib
! pip install pingouin 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import pingouin as pg
# Out:
# ...
#   Using cached pingouin-0.3.12-py3-none-any.whl
# ...
#   Using cached statsmodels-0.12.2-cp38-cp38-manylinux1_x86_64.whl (9.4 MB)
# ...
#   Using cached outdated-0.2.1-py3-none-any.whl (7.5 kB)
# ...
#   Using cached pandas_flavor-0.2.0-py2.py3-none-any.whl (6.6 kB)
# ...
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# ...
#   Using cached scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# ...
#   Using cached xarray-0.18.2-py3-none-any.whl (807 kB)
# ...
#   Using cached patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# ...
#   Using cached littleutils-0.2.2-py3-none-any.whl
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...

# %%
df = pd.read_csv('final_df.csv')
df["Year"] = df["Unnamed: 0"]
df = df.drop(["Unnamed: 0"], axis=1)
df = df.set_index(["Year"]).T
#35 rows, 16 columns(2004-2019)
df
# Out:
# Year                                                        2004  \
# Food exports (% of merchandise exports)             2.788167e+01
# GDP (constant 2010 US$)                             1.720000e+12
# GDP per capita (constant 2010 US$)                  9.346039e+03
# Forest area (sq. km)                                5.352854e+06
# Goods exports (BoP, current US$)                    9.624064e+10
# Net trade in goods and services (BoP, current US$)  2.898951e+10
# Imports of goods and services (BoP, current US$)    7.899524e+10
# Forest area (% of land area)                        6.404361e+01
# International tourism, number of arrivals           4.794000e+06
# Unemployment, total (% of total labor force) (m...  9.110000e+00
# Unemployment with advanced education, male (% o...  2.960000e+00
# GNI (current US$)                                   6.500000e+11
# Gross capital formation (% of GDP)                  1.791257e+01
# ...

# %%
flipped_df = df.transpose()
flipped_df
# Out:
#       Food exports (% of merchandise exports)  GDP (constant 2010 US$)  \
# Year
# 2004                                27.881671             1.720000e+12
# 2005                                25.674871             1.770000e+12
# 2006                                24.919965             1.850000e+12
# 2007                                26.221861             1.960000e+12
# 2008                                27.433868             2.060000e+12
# 2009                                33.890589             2.050000e+12
# 2010                                30.129393             2.210000e+12
# 2011                                30.225503             2.300000e+12
# 2012                                31.839229             2.340000e+12
# 2013                                33.924319             2.410000e+12
# 2014                                35.026734             2.420000e+12
# 2015                                37.138500             2.340000e+12
# ...

# %%
flipped_df["GDP (constant 2010 US$)"].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
flipped_df["Total Deforestation"].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
a = flipped_df["Total Deforestation"]
b = flipped_df["GDP (constant 2010 US$)"]
pg.ttest(a,b)
# Out:
#                 T  dof       tail         p-val  \
# T-test -37.300641   30  two-sided  1.072656e-26
#
#                                          CI95%    cohen-d      BF10  power
# T-test  [-2284196579671.14, -2047053400286.99]  13.187768  1.11e+23    1.0
